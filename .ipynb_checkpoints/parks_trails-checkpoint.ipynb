# %%
import pandas as pd
df = pd.read_csv('parks_trails.csv')

# %%
df.head()
# Out:
#    OBJECTID *     Shape *  Join_Count  TARGET_FID  JOIN_FID  \
# 0         169  Polygon ZM           1          53        10
# 1         170  Polygon ZM           1          53        11
# 2         171  Polygon ZM           1          53        38
# 3         172  Polygon ZM           1          53        46
# 4         173  Polygon ZM           1          53        53
#
#                           NAME        ACRE PARK_MGNT_REGION  \
# 0  Alderfer/Three Sisters Park  1127.72109        Mountains
# 1  Alderfer/Three Sisters Park  1127.72109        Mountains
# 2  Alderfer/Three Sisters Park  1127.72109        Mountains
# 3  Alderfer/Three Sisters Park  1127.72109        Mountains
# 4  Alderfer/Three Sisters Park  1127.72109        Mountains
#
#              MANAGER              OWNER     ...      Shape__Length  \
# 0  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
# 1  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
# 2  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
# 3  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
# 4  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
#
#            TRAIL_NAME                    PARK_NAME   MILEAGE  \
# 0   Cone Flower Trail  Alderfer Three Sisters Park  0.223226
# 1              <Null>  Alderfer Three Sisters Park  0.076662
# 2     Bearberry Trail  Alderfer Three Sisters Park  1.202917
# 3  Evergreen Mtn West  Alderfer Three Sisters Park  1.106279
# 4     Homestead Trail  Alderfer Three Sisters Park  0.286830
#
#               TRAIL_DIFFICULTY_RATING  MILEAGE_ROUNDED  USER_TYPE  \
# 0                     Least Difficult              0.2  Multi-Use
# 1                     Least Difficult              0.1  Multi-Use
# 2                     Least Difficult              1.2  Multi-Use
# 3  Least Difficult and More Difficult              1.1  Multi-Use
# 4                      More Difficult              0.3  Multi-Use
#
#        iff_reclass  Shape_Length   Shape_Area
# 0  Least Difficult   1178.632738  49123334.18
# 1  Least Difficult    404.773961  49123334.18
# 2  Least Difficult   6351.400408  49123334.18
# 3   More Difficult   5841.151631  49123334.18
# 4   More Difficult   1514.461695  49123334.18
#
# [5 rows x 25 columns]

# %%
df.iff_reclass.unique()
# there are nan(s) in this column
# Out:
# array(['Least Difficult', 'More Difficult', 'Most Difficult', nan], dtype=object)

# %%
df.fillna('Unlisted', inplace=True)
df.head()
# Out:
#    OBJECTID *     Shape *  Join_Count  TARGET_FID  JOIN_FID  \
# 0         169  Polygon ZM           1          53        10
# 1         170  Polygon ZM           1          53        11
# 2         171  Polygon ZM           1          53        38
# 3         172  Polygon ZM           1          53        46
# 4         173  Polygon ZM           1          53        53
#
#                           NAME        ACRE PARK_MGNT_REGION  \
# 0  Alderfer/Three Sisters Park  1127.72109        Mountains
# 1  Alderfer/Three Sisters Park  1127.72109        Mountains
# 2  Alderfer/Three Sisters Park  1127.72109        Mountains
# 3  Alderfer/Three Sisters Park  1127.72109        Mountains
# 4  Alderfer/Three Sisters Park  1127.72109        Mountains
#
#              MANAGER              OWNER     ...      Shape__Length  \
# 0  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
# 1  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
# 2  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
# 3  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
# 4  Jeffco Open Space  Jeffco Open Space     ...         44933.2373
#
#            TRAIL_NAME                    PARK_NAME   MILEAGE  \
# 0   Cone Flower Trail  Alderfer Three Sisters Park  0.223226
# 1              <Null>  Alderfer Three Sisters Park  0.076662
# 2     Bearberry Trail  Alderfer Three Sisters Park  1.202917
# 3  Evergreen Mtn West  Alderfer Three Sisters Park  1.106279
# 4     Homestead Trail  Alderfer Three Sisters Park  0.286830
#
#               TRAIL_DIFFICULTY_RATING  MILEAGE_ROUNDED  USER_TYPE  \
# 0                     Least Difficult              0.2  Multi-Use
# 1                     Least Difficult              0.1  Multi-Use
# 2                     Least Difficult              1.2  Multi-Use
# 3  Least Difficult and More Difficult              1.1  Multi-Use
# 4                      More Difficult              0.3  Multi-Use
#
#        iff_reclass  Shape_Length   Shape_Area
# 0  Least Difficult   1178.632738  49123334.18
# 1  Least Difficult    404.773961  49123334.18
# 2  Least Difficult   6351.400408  49123334.18
# 3   More Difficult   5841.151631  49123334.18
# 4   More Difficult   1514.461695  49123334.18
#
# [5 rows x 25 columns]

# %%
df.iff_reclass.unique()
# Out:
# array(['Least Difficult', 'More Difficult', 'Most Difficult', 'Unlisted'], dtype=object)

# %%
import numpy as np
table = pd.pivot_table(data=df, values='MILEAGE_ROUNDED', index=['PARK_NAME', 'iff_reclass'], aggfunc=np.sum)
table
# Out:
#                                                              MILEAGE_ROUNDED
# PARK_NAME                                   iff_reclass
# Alderfer Three Sisters Park                 Least Difficult             4.31
#                                             More Difficult             11.03
#                                             Most Difficult              0.60
# Apex Park                                   Most Difficult              0.70
# Cathedral Spires Park                       Most Difficult              1.30
# Centennial Cone Park                        Least Difficult             4.30
#                                             More Difficult             35.50
# Clear Creek Canyon Park                     More Difficult              1.90
# Crown Hill Park                             Least Difficult            10.42
# Crown Hill Park                             Least Difficult             0.02
# Deer Creek Canyon Park                      Least Difficult             1.21
#                                             More Difficult             17.00
#                                             Most Difficult              1.60
#                                             Unlisted                    0.10
# Flying J Ranch Park                         Least Difficult             3.70
#                                             Unlisted                    0.30
# Hildebrand Ranch                            Least Difficult             0.05
# Hildebrand Ranch                            Least Difficult             0.05
# Hildebrand Ranch Park                       Least Difficult             3.90
# Hiwan Homestead Museum                      Least Difficult             0.30
# Lair o the Bear Park                        Least Difficult             1.80
#                                             More Difficult              7.10
# Lookout Mountain Nature Center and Preserve Least Difficult             2.78
#                                             More Difficult              0.60
# Matthews/Winters Park                       Least Difficult             0.95
#                                             More Difficult              3.70
#                                             Most Difficult              2.40
#                                             Unlisted                    0.16
# Meadowbrook Village Park                    Least Difficult             0.40
# Meyer Ranch Park                            Least Difficult             1.90
#                                             More Difficult              2.10
# Mount Falcon Park                           Least Difficult             2.02
#                                             More Difficult              7.90
#                                             Most Difficult              2.40
#                                             Unlisted                    0.07
# Mount Galbraith Park                        More Difficult              6.20
# Mount Glennon                               Unlisted                    0.10
# Non-Jeffco Open Space                       Least Difficult            13.00
#                                             Most Difficult              1.30
# North Table Mountain Park                   Least Difficult             5.59
#                                             More Difficult              9.00
#                                             Most Difficult              2.50
#                                             Unlisted                    0.20
# Pine Valley Ranch Park                      Least Difficult             3.78
#                                             More Difficult              2.10
# Reynolds Park                               Least Difficult             1.13
#                                             More Difficult             32.40
#                                             Unlisted                    0.32
# South Table Mountain Park                   Least Difficult             4.20
#                                             More Difficult              3.60
#                                             Unlisted                    0.08
# Unlisted                                    More Difficult              0.90
# Van Bibber                                  Least Difficult             0.04
# Van Bibber Park                             Least Difficult             4.85
# Welchester Tree Grant Park                  Least Difficult             0.64
# White Ranch Park                            Least Difficult             1.90
#                                             More Difficult             12.50
#                                             Most Difficult              6.40
#                                             Unlisted                    0.34
# Windy Saddle Park                           More Difficult              0.60
